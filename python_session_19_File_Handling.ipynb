# %% [markdown]
# # File handling

# %%
# File Name          Type of file
========================= Structures and Semi-Structured ======================
- Text              .txt
- word              .doc or .docx
- Pdf               .pdf
- CSV(Excel)        .csv (Comma seperated value)(tabular)
- Excel             .xlsx (Tabular)
- json              .json (Dictionary key-value)
============================== Unstructured ===================================
- XML               .xml (Image data)
- Parquet           .delta/.parquet (DE)
- Delta             .delta (DE)
- Image             .jpg,.JPEG,.png
- Video             .mp4
- Audio            .mp3

# %% [markdown]
# **How to read file**
#
# - inorder to read the files
# - We need three things
# - 1. File directory
# - 2. File name
# - 3. File extension

# %%
C:\Users\Asef\OneDrive\Documents\Data files
# Out:
#   Cell In[4], line 1
#     C:\Users\Asef\OneDrive\Documents\Data files
#        ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# **unicode error**
#
# - The file path has single slash ''
#
# - Python extect a double slash '\'
#
# - change '' to '\'
#
# - otherwise apply 'r' at the starting
#
# - r means raw string

# %%
"C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
# Out:
#   Cell In[21], line 1
#     "C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
#     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
"C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
# Out:
#   Cell In[19], line 1
#     "C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
#     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
r"C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
# Out:
# 'C:\\Users\\Asef\\OneDrive\\Documents\\NareshIT\\Data files\\mbox-short.txt'

# %%
"C:\\Users\\Asef\\OneDrive\\Documents\\NareshIT\\Data files\\mbox-short.txt"
# Out:
# 'C:\\Users\\Asef\\OneDrive\\Documents\\NareshIT\\Data files\\mbox-short.txt'

# %%
r"C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
# Out:
# 'C:\\Users\\Asef\\OneDrive\\Documents\\NareshIT\\Data files\\mbox-short.txt'

# %%
"C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
# Out:
#   Cell In[11], line 1
#     "C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
#     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
path=path=r"C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
file=open(path)
data=file.read()
print(data)
file=open(path)
data=file.read()
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
path=r"C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
open(path)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Asef\\OneDrive\\Documents\\NareshIT\\Data files\\mbox-short.txt' mode='r' encoding='cp1252'>

# %% [markdown]
# **Method-2**
#
# - In method-1 we have seen the file path in defferent location
#
# - Imagine that the file path available where your python file located
#
# - means both datafile and python file are at same location
#
# - qn: where is your phton file located
#
# - copy the mboc-short file at same loation

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Asef\\Documents\\NareshIT\\Python'

# %%
path='mbox-short.txt'
file=open(path)
data=file.read()
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %% [markdown]
# **method-3**
#
# - Some times reading session closed so that we are not able to see the output
#
# - In that situations read the file using with keyword

# %%
path='mbox-short.txt'
with open(path) as file:
 data=file.read()
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
complex()
# Out:
# 0j

# %%
complex(2,3)
# Out:
# (2+3j)

# %%
path="mbox-short.txt"
file=open(path)
data=file.read()
print(data)
# you want to write hello good morning
# into some file
# first you will create one empty file
# newfile: example.txt
# change the mode into 'w'
# change file.read to file.write('hello good')

# %%
path="example1.txt"
file=open(path,mode='w')
data=file.write('Hello Good morning')
print(data)
# Out:
# 18

# %%
# Idont want save example.txt at python location
# I want save in a new folder
# that folder should presnt at python location
# create a folder files
path=r"C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
file=open(path,mode='w')
data=file.write('Hello Good morning')
print(data)
# Out:
# 18

# %%
file=open(path,mode='r')
data=file.read()
print(data)
# Out:
# Hello Good morning

# %%
# Idont want save example.txt at python location
# I want save in a new folder
# that folder should presnt at python location
# create a folder files
path=r"C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
file=open(path,mode='w')
data=file.write('Hello Good morning')
print(data)
# Out:
# 18

# %%
file=open(path,mode='r')
data=file.read()
print(data)
# Out:
# Hello Good morning

# %%
path=r"C:\Users\Asef\OneDrive\Documents\NareshIT\Data files\mbox-short.txt"
with open(path,mode='w') as file:
 file.write('Hello Good morning')

# %%
# we created folder manually
# now we will create the folder using python
# and the path should go automatically

# %%
# Q1) what is the name of the folder you want to create
 # Ans: files1
# Q2) where you want to create : dir
 # Ans: where our python file located
# Give me the ans2 using python code

# %%
import os
dir=os.getcwd() # Ans2
folder='files2' # Ans1
#new_dir=dir+"\\"+folder
new_dir=os.path.join(dir,folder) # i made my path
os.makedirs(new_dir) # create the folder

# %%
try:
 dir=os.getcwd() 
 folder='files2' 
 new_dir=os.path.join(dir,folder)
 os.makedirs(new_dir)
except Exception as e:
 print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Asef\\Documents\\NareshIT\\Python\\files2'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Asef\\Documents\\NareshIT\\Python'

# %%
file_name='example3.txt'
new_dir
path=os.path.join(new_dir,file_name)
with open(path,mode='w') as file:
 file.write('Hello Good morning')

# %%
# Understand the full path first
# break into two one dir, file name
# join using python syntax

# %%
import os
folder='files3'
file_name='example4.txt'
################ Create new dir #############
dir=os.getcwd() 
new_dir=os.path.join(dir,folder)
os.makedirs(new_dir)
############# Creating a file ############# 
path=os.path.join(new_dir,file_name)
with open(path,mode='w') as file:
 file.write('Hello Good morning')

# %%
open()
'r' open for reading (default)
'w' open for writing, truncating the file first
'x' create a new file and open it for writing
'a' open for writing, appending to the end of the file if it exists
'b' binary mode

# %%
path=os.path.join(os.getcwd(),filename)
with open(path,mode='r') as file:
 file.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 path=os.path.join(os.getcwd(),filename)
#       2 with open(path,mode='r') as file:
#       3  file.read()
#
# NameError: name 'filename' is not defined

# %%
=====================================================================================================

# %%
path='mbox-short.txt'
with open(path,
          mode='r',
          encoding='utf-8-sig') as file:
     data=file.read()
print(data)

# %%
# Q2) Ans

path="mbox-short.txt"
file=open(path)
from_list=[]
for line in file:
    if line.startwith('From'):
        from_list.append(line)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 7
#       5 from_list=[]
#       6 for line in file:
# ----> 7     if line.startwith('From'):
#       8         from_list.append(line)
#
# AttributeError: 'str' object has no attribute 'startwith'

# %%
len(from_list)
# 54 len
# Out:
# 0

# %%
# Q3) 

path="mbox-short.txt"
file=open(path)
from_list=[line for line in file if line.startwith('From')]
len(from_list)

# output is 54
# Out:
# 0

# %%
from_list[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 from_list[0]
#
# IndexError: list index out of range

# %%
# Q4)

# %%
list1[0].split()[1]

# output is imail id

# %%
list1[1].split()[1]

# output is email id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 list1[1].split()[1]
#
# NameError: name 'list1' is not defined

# %%
# Q5) 
emails=[]
for i in range(len(list1))

# %%
# Q6) uique

set(emails)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 # Q6) uique
# ----> 3 set(emails)
#
# NameError: name 'emails' is not defined
